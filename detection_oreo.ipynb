# %%
### Juste si le dossier yolo n'est pas déjà présent :
# !git clone https://github.com/ultralytics/yolov5
# Out:
# 'git' n'est pas reconnu en tant que commande interne
# ou externe, un programme ex�cutable ou un fichier de commandes.

# %% [markdown]
# Etapes :
#
# 1) Ouvrir google collab -> https://colab.research.google.com/github/ultralytics/yolov5/blob/master/tutorial.ipynb#scrollTo=1NcFxRcFdJ_O
#
# 2) "Connecter" pour avoir l'attribution de ressources
#
# 3) Exécuter la cellule 'SetUp'
#
# 4) Importer le dossier avec les images/labélisations (en .zip) dans google collab (au même niveau que le dossier yolov5)
#
# 5) Dézipper le dossier -> !unzip -q ../datasets_ggl.zip -d ../
#
# 6) Importer le fichier oreo_data.yaml dans yolov5/data
#
# 7) Lancer l'entrainement dans google collab avec les paramètres voulus
#
# 8) Récupérer les poids trouver lors de l'entrainement et les mettre dans ../ggl/weight/nouveau_dossier
#
# 9) Lancer l'étape de détection (en spécifiant le chemin d'accès aux poids) avec une source vidéo, une photo, ou directement la caméra pour le faire en temps réél (pour ça faire '--source 0'

# %%
# Etape 0 : A executer une fois à l'ouverture du projet dans jupiter (avant detection)
#%cd golikova-levy-plong-2022
# %cd ..
# %cd yolov5
# %pip install -qr requirements.txt  
# install

import torch
import utils
display = utils.notebook_init()  
# checks
# Out:
# [WinError 2] Le fichier spécifié est introuvable: 'golikova-levy-plong-2022'
# c:\Users\remil\OneDrive\Bureau\Projets Université\golikova-levy-plong-2022
# c:\Users\remil\OneDrive\Bureau\Projets Université\golikova-levy-plong-2022\yolov5
# Note: you may need to restart the kernel to use updated packages.
# Checking setup...

# %%
# ------- Etape 1 : Setup - A lancer dans google collab

# !git clone https://github.com/ultralytics/yolov5  # clone
# %cd yolov5
# %pip install -qr requirements.txt  # install

import torch
import utils
display = utils.notebook_init()  # checks
# Out:
# [WinError 2] Le fichier spécifié est introuvable: 'yolov5'
# C:\Users\remil\OneDrive\Bureau\golikova-levy-plong-2022
# fatal: Too many arguments.
#
# usage: git clone [<options>] [--] <repo> [<dir>]
#
#     -v, --verbose         be more verbose
#     -q, --quiet           be more quiet
#     --progress            force progress reporting
#     -n, --no-checkout     don't create a checkout
#     --bare                create a bare repository
#     --mirror              create a mirror repository (implies bare)
#     -l, --local           to clone from a local repository
#     --no-hardlinks        don't use local hardlinks, always copy
#     -s, --shared          setup as shared repository
#     --recurse-submodules[=<pathspec>]
#                           initialize submodules in the clone
#     --recursive ...       alias of --recurse-submodules
#     -j, --jobs <n>        number of submodules cloned in parallel
#     --template <template-directory>
# ...

# %%
# ------- Etape 2 : Entrainement - A lancer dans google collab aussi 

# Note : Pour le moment tous les entrainement avec 16 batch et 50 epochs
# !python train.py --img 640 --batch 16 --epochs 50 --data oreo_data.yaml --weights yolov5s.pt --cache

# Trouver les courbes de pertes dans result.png
# TODO : Trouver comment afficher les fonctions de perte et différents graphiques

# %%
# ------- Etape 3 : Détection - Après avoir importé les poids trouvés dans google collab

# ----- Détection à partir des poids trouvés : 

# * A partir d'une vidéo :
#!python detect.py --weights ../ggl/weight/v2_YOLO_poids_ajout_non_oreos/best.pt --img 640 --conf 0.25 --source ../video.mp4
#!python detect.py --weights ../ggl/weight/v4_YOLO_tous_ech_mais_30epochs/best.pt --img 640 --conf 0.25 --source ../video.mp4
# !python detect.py --weights ../ggl/weight/v5_YOLO_20epochs_new_images/best.pt --img 640 --conf 0.25 --source 0

# * A partir de la caméra, en temps réel 
#!python detect.py --weights ../ggl/weight/v2_YOLO_poids_ajout_non_oreos/best.pt --img 640 --conf 0.25 --source 0

# La vidéo "resultat" se trouve dans runs/detect/expN avec N le dernier numéro d'execution
# Out:
# detect: weights=['../ggl/weight/v5_YOLO_20epochs_new_images/best.pt'], source=0, data=data\coco128.yaml, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs\detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5  v7.0-32-g357cde9 Python-3.8.8 torch-1.13.0+cpu CPU
#
# Fusing layers...
# Model summary: 157 layers, 7023610 parameters, 0 gradients, 15.8 GFLOPs
# 1/1: 0...  Success (inf frames 640x480 at 30.00 FPS)
#
# 0: 480x640 (no detections), 257.0ms
# 0: 480x640 (no detections), 257.3ms
# 0: 480x640 (no detections), 172.3ms
# 0: 480x640 (no detections), 236.5ms
# 0: 480x640 (no detections), 219.1ms
# 0: 480x640 (no detections), 222.9ms
# 0: 480x640 (no detections), 225.8ms
# 0: 480x640 (no detections), 210.8ms
# ...
